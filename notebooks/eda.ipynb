# %%
import pandas as pd

df = pd.read_csv('../dataset/application_train.csv')

print(df.head())
print(df.info())

# %%
df = pd.read_csv('../dataset/application_test.csv')

df.head()
df.info()

# %%
df = pd.read_csv('../dataset/bureau_balance.csv')

df.head()
df.info()

# %%
df = pd.read_csv('../dataset/bureau.csv')

df.head()
df.info()

# %%
df = pd.read_csv('../dataset/credit_card_balance.csv')

df.head()
df.info()

# %%
df = pd.read_csv('../dataset/POS_CASH_balance.csv')

df.head()
df.info()

# %%
df = pd.read_csv('../dataset/previous_application.csv')

df.head()
df.info()

# %%
df = pd.read_csv('../dataset/sample_submission.csv')

df.head()
df.info()
